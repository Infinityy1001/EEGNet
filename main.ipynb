# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
import numpy as np
import mne
from glob import glob
import pandas as pd

# %%
# Paramètres
Fs = 256  # Fréquence d'échantillonnage
n_channels = 4  # Nombre de canaux
Wn = 1  # Durée de la fenêtre d'échantillonnage
n_samples = Wn * Fs  # Longueur de la fenêtre d'échantillonnage
batch_size = 32
epochs = 500
n_ff = [2, 4, 8, 16]  # Nombre de filtres de fréquence pour chaque module d'inception
n_sf = [1, 1, 1, 1]  # Nombre de filtres spatiaux dans chaque sous-bande de fréquence

# %%
def convertDF2MNE(sub):
    info = mne.create_info(list(sub.columns), ch_types=['eeg'] * len(sub.columns), sfreq=256)
    info.set_montage('standard_1020')
    data = mne.io.RawArray(sub.T, info)
    data.set_eeg_reference()
    epochs = mne.make_fixed_length_epochs(data, duration=Wn, overlap=0.2 * Wn)
    return epochs.get_data()

# %%
# Charger et traiter les données
def load_data():
    files1 = glob("dataset//Train//*gauche*")
    files2 = glob("dataset//Train//*droite*")
    files3 = glob("dataset//Train//*neutre*")

    dfs1, dfs2, dfs3 = [], [], []
    for f in files1:
        df = pd.read_csv(f)
        cols_remove = ['timestamps', 'Right AUX']
        df = df.loc[:, ~df.columns.isin(cols_remove)]
        df.columns = df.columns.str.replace('RAW_', '', 1)
        df = df.fillna(df.mean())
        dfs1.append(df)  
    data1 = pd.concat(dfs1, ignore_index=True)

    for f in files2:
        df = pd.read_csv(f)
        cols_remove = ['timestamps', 'Right AUX']
        df = df.loc[:, ~df.columns.isin(cols_remove)]
        df.columns = df.columns.str.replace('RAW_', '', 1)
        df = df.fillna(df.mean())
        dfs2.append(df)  
    data2 = pd.concat(dfs2, ignore_index=True)

    for f in files3:
        df = pd.read_csv(f)
        cols_remove = ['timestamps', 'Right AUX']
        df = df.loc[:, ~df.columns.isin(cols_remove)]
        df.columns = df.columns.str.replace('RAW_', '', 1)
        df = df.fillna(df.mean())
        dfs3.append(df)  
    data3 = pd.concat(dfs3, ignore_index=True)

    x_left = np.empty((0, n_channels, n_samples))
    y_left = np.empty(0)
    x_right = np.empty((0, n_channels, n_samples))
    y_right = np.empty(0)
    x_neutral = np.empty((0, n_channels, n_samples))
    y_neutral = np.empty(0)

    # Convertir les données
    data = convertDF2MNE(data1)
    for i in range(len(data)):
        label = 0
        y_left = np.append(y_left, label)
    x_left = np.append(x_left, data, axis=0)

    data = convertDF2MNE(data2)
    for i in range(len(data)):
        label = 1
        y_right = np.append(y_right, label)
    x_right = np.append(x_right, data, axis=0)

    data = convertDF2MNE(data3)
    for i in range(len(data)):
        label = 2
        y_neutral = np.append(y_neutral, label)
    x_neutral = np.append(x_neutral, data, axis=0)

    x_left = x_left[:, :, :, np.newaxis]
    x_right = x_right[:, :, :, np.newaxis]
    x_neutral = x_neutral[:, :, :, np.newaxis]

    split = 64
    x_train = np.concatenate((x_left[split:, :, :, :], x_right[split:, :, :, :], x_neutral[split:, :, :, :]), axis=0)
    x_val = np.concatenate((x_left[:split, :, :, :], x_right[:split, :, :, :], x_neutral[split:, :, :, :]), axis=0)

    y_train = np.concatenate((y_left[split:], y_right[split:], y_neutral[split:]))
    y_val = np.concatenate((y_left[:split], y_right[:split], y_neutral[split:]))

    return x_train, y_train, x_val, y_val

# %%
class EEGNet(nn.Module):
    def __init__(self, num_classes = 3):
        super(EEGNet, self).__init__()
        
        # Première couche de convolution
        self.conv1 = nn.Conv2d(in_channels=4, out_channels=2, kernel_size=(1, 4), stride=1, padding=(0, 2))
        self.batch_norm1 = nn.BatchNorm2d(2)
        self.activation1 = nn.ReLU()

        # Ajouter la couche depthwise
        self.depthwise_conv1 = nn.Conv2d(in_channels=2, out_channels=4, kernel_size=(2, 1), stride=1, padding=0)
        self.batch_norm2 = nn.BatchNorm2d(4)
        self.activation2 = nn.ReLU()

        # Définir une couche conv2 (si nécessaire)
        self.conv2 = nn.Conv2d(in_channels=4, out_channels=8, kernel_size=(1, 3), stride=1, padding=(0, 1))  # Par exemple
        self.batch_norm3 = nn.BatchNorm2d(8)
        self.activation3 = nn.ReLU()

        # Couches fully connected
        self.fc = nn.Linear(8 * 255 * 2, 64)  # 8 * 255 * 2 = 4080
        self.out = nn.Linear(64, num_classes)  # Par exemple, 28 classes
        self.dropout = nn.Dropout(0.5)

    def forward(self, x):
        # Appliquer les convolutions et activations
        x = self.conv1(x)
        x = self.batch_norm1(x)
        x = self.activation1(x)

        x = self.depthwise_conv1(x)
        x = self.batch_norm2(x)
        x = self.activation2(x)

        x = self.conv2(x)
        x = self.batch_norm3(x)
        x = self.activation3(x)

        # Vérifier les dimensions de x avant de passer à la couche fully connected
        # print(x.shape)  # Ajouter cette ligne pour vérifier les dimensions

        # Appliquer la couche fully connected
        x = x.view(x.size(0), -1)  # Aplatir la sortie
        x = self.fc(x)  # Passer à la couche fully connected
        x = self.dropout(x)
        x = self.out(x) 

        return x

# %%
class EEGDataset(Dataset):
    def __init__(self, data, labels):
        self.data = torch.tensor(data, dtype=torch.float32)
        self.labels = torch.tensor(labels, dtype=torch.long)

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        return self.data[idx], self.labels[idx]

# %%
x_train, y_train, x_val, y_val = load_data()

# Créer les DataLoaders
train_dataset = EEGDataset(x_train, y_train)
val_dataset = EEGDataset(x_val, y_val)
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
# Out:
# Creating RawArray with float64 data, n_channels=4, n_times=172023
#     Range : 0 ... 172022 =      0.000 ...   671.961 secs
# Ready.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Not setting metadata
# 839 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 839 events and 256 original time points ...
# 0 bad epochs dropped
# Creating RawArray with float64 data, n_channels=4, n_times=119145
#     Range : 0 ... 119144 =      0.000 ...   465.406 secs
# Ready.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Not setting metadata
# 581 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 581 events and 256 original time points ...
# 0 bad epochs dropped
# Creating RawArray with float64 data, n_channels=4, n_times=104930
#     Range : 0 ... 104929 =      0.000 ...   409.879 secs
# Ready.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Not setting metadata
# 512 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 512 events and 256 original time points ...
# 0 bad epochs dropped

# %%
model = EEGNet()
optimizer = optim.Adam(model.parameters(), lr=0.001)
criterion = nn.CrossEntropyLoss()

# %%
# Entraînement du modèle
for epoch in range(epochs):
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0
    
    for inputs, labels in train_loader:
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        _, predicted = torch.max(outputs, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

    epoch_loss = running_loss / len(train_loader)
    accuracy = 100 * correct / total
    print(f"Epoch {epoch+1}/{epochs}, Loss: {epoch_loss:.4f}, Accuracy: {accuracy:.2f}%")
# Out:
# Epoch 1/500, Loss: 1.2540, Accuracy: 44.77%
# Epoch 2/500, Loss: 0.9609, Accuracy: 55.69%
# Epoch 3/500, Loss: 0.8020, Accuracy: 64.43%
# Epoch 4/500, Loss: 0.7250, Accuracy: 68.85%
# Epoch 5/500, Loss: 0.6315, Accuracy: 73.79%
# Epoch 6/500, Loss: 0.5556, Accuracy: 77.41%
# Epoch 7/500, Loss: 0.5045, Accuracy: 79.54%
# Epoch 8/500, Loss: 0.4302, Accuracy: 85.57%
# Epoch 9/500, Loss: 0.3851, Accuracy: 85.46%
# Epoch 10/500, Loss: 0.4032, Accuracy: 85.29%
# Epoch 11/500, Loss: 0.3845, Accuracy: 84.94%
# Epoch 12/500, Loss: 0.3091, Accuracy: 89.48%
# Epoch 13/500, Loss: 0.2548, Accuracy: 90.63%
# Epoch 14/500, Loss: 0.1833, Accuracy: 93.45%
# Epoch 15/500, Loss: 0.2069, Accuracy: 93.74%
# Epoch 16/500, Loss: 0.1821, Accuracy: 93.51%
# Epoch 17/500, Loss: 0.1784, Accuracy: 94.31%
# Epoch 18/500, Loss: 0.1681, Accuracy: 93.91%
# Epoch 19/500, Loss: 0.1759, Accuracy: 94.08%
# Epoch 20/500, Loss: 0.1495, Accuracy: 95.34%
# Epoch 21/500, Loss: 0.0918, Accuracy: 96.84%
# Epoch 22/500, Loss: 0.1047, Accuracy: 96.72%
# Epoch 23/500, Loss: 0.0923, Accuracy: 97.30%
# Epoch 24/500, Loss: 0.1241, Accuracy: 95.23%
# Epoch 25/500, Loss: 0.1075, Accuracy: 96.67%
# Epoch 26/500, Loss: 0.1130, Accuracy: 96.78%
# Epoch 27/500, Loss: 0.0817, Accuracy: 97.30%
# Epoch 28/500, Loss: 0.0898, Accuracy: 97.30%
# Epoch 29/500, Loss: 0.1025, Accuracy: 96.38%
# Epoch 30/500, Loss: 0.0920, Accuracy: 96.67%
# Epoch 31/500, Loss: 0.0848, Accuracy: 97.53%
# Epoch 32/500, Loss: 0.1251, Accuracy: 96.21%
# Epoch 33/500, Loss: 0.0819, Accuracy: 97.13%
# Epoch 34/500, Loss: 0.0585, Accuracy: 98.28%
# Epoch 35/500, Loss: 0.0592, Accuracy: 98.22%
# Epoch 36/500, Loss: 0.0299, Accuracy: 99.25%
# Epoch 37/500, Loss: 0.0265, Accuracy: 99.37%
# Epoch 38/500, Loss: 0.0311, Accuracy: 98.91%
# Epoch 39/500, Loss: 0.1132, Accuracy: 96.26%
# Epoch 40/500, Loss: 0.0672, Accuracy: 98.33%
# Epoch 41/500, Loss: 0.0565, Accuracy: 98.22%
# Epoch 42/500, Loss: 0.0424, Accuracy: 99.08%
# Epoch 43/500, Loss: 0.0338, Accuracy: 98.97%
# Epoch 44/500, Loss: 0.0380, Accuracy: 99.14%
# Epoch 45/500, Loss: 0.0441, Accuracy: 98.79%
# Epoch 46/500, Loss: 0.0371, Accuracy: 98.97%
# Epoch 47/500, Loss: 0.0443, Accuracy: 98.79%
# Epoch 48/500, Loss: 0.0332, Accuracy: 99.20%
# Epoch 49/500, Loss: 0.0175, Accuracy: 99.54%
# Epoch 50/500, Loss: 0.0263, Accuracy: 99.08%
# Epoch 51/500, Loss: 0.0476, Accuracy: 98.33%
# Epoch 52/500, Loss: 0.0743, Accuracy: 97.64%
# Epoch 53/500, Loss: 0.0227, Accuracy: 99.66%
# Epoch 54/500, Loss: 0.0272, Accuracy: 99.08%
# Epoch 55/500, Loss: 0.0302, Accuracy: 99.20%
# Epoch 56/500, Loss: 0.0719, Accuracy: 97.59%
# Epoch 57/500, Loss: 0.0556, Accuracy: 98.33%
# Epoch 58/500, Loss: 0.1001, Accuracy: 97.70%
# Epoch 59/500, Loss: 0.3268, Accuracy: 91.15%
# Epoch 60/500, Loss: 0.0558, Accuracy: 98.39%
# Epoch 61/500, Loss: 0.0589, Accuracy: 98.39%
# Epoch 62/500, Loss: 0.0187, Accuracy: 99.60%
# Epoch 63/500, Loss: 0.0302, Accuracy: 98.91%
# Epoch 64/500, Loss: 0.0280, Accuracy: 99.25%
# Epoch 65/500, Loss: 0.0245, Accuracy: 99.54%
# Epoch 66/500, Loss: 0.0155, Accuracy: 99.71%
# Epoch 67/500, Loss: 0.0134, Accuracy: 99.60%
# Epoch 68/500, Loss: 0.0120, Accuracy: 99.89%
# Epoch 69/500, Loss: 0.0103, Accuracy: 99.83%
# Epoch 70/500, Loss: 0.0160, Accuracy: 99.83%
# Epoch 71/500, Loss: 0.0241, Accuracy: 99.48%
# Epoch 72/500, Loss: 0.0171, Accuracy: 99.77%
# Epoch 73/500, Loss: 0.0083, Accuracy: 99.83%
# Epoch 74/500, Loss: 0.0043, Accuracy: 100.00%
# Epoch 75/500, Loss: 0.0051, Accuracy: 99.94%
# Epoch 76/500, Loss: 0.0085, Accuracy: 99.77%
# Epoch 77/500, Loss: 0.0190, Accuracy: 99.25%
# Epoch 78/500, Loss: 0.0189, Accuracy: 99.37%
# Epoch 79/500, Loss: 0.0192, Accuracy: 99.48%
# Epoch 80/500, Loss: 0.0093, Accuracy: 99.83%
# Epoch 81/500, Loss: 0.0117, Accuracy: 99.60%
# Epoch 82/500, Loss: 0.0254, Accuracy: 99.20%
# Epoch 83/500, Loss: 0.0438, Accuracy: 99.14%
# Epoch 84/500, Loss: 0.0855, Accuracy: 97.64%
# Epoch 85/500, Loss: 0.1013, Accuracy: 97.18%
# Epoch 86/500, Loss: 0.0294, Accuracy: 98.74%
# Epoch 87/500, Loss: 0.0198, Accuracy: 99.37%
# Epoch 88/500, Loss: 0.0290, Accuracy: 99.37%
# Epoch 89/500, Loss: 0.0139, Accuracy: 99.66%
# Epoch 90/500, Loss: 0.0077, Accuracy: 99.83%
# Epoch 91/500, Loss: 0.0233, Accuracy: 99.37%
# Epoch 92/500, Loss: 0.0176, Accuracy: 99.25%
# Epoch 93/500, Loss: 0.0507, Accuracy: 98.51%
# Epoch 94/500, Loss: 0.0340, Accuracy: 98.91%
# Epoch 95/500, Loss: 0.0158, Accuracy: 99.48%
# Epoch 96/500, Loss: 0.0223, Accuracy: 99.48%
# Epoch 97/500, Loss: 0.0240, Accuracy: 99.37%
# Epoch 98/500, Loss: 0.0342, Accuracy: 99.08%
# Epoch 99/500, Loss: 0.0257, Accuracy: 99.54%
# Epoch 100/500, Loss: 0.0355, Accuracy: 99.14%
# Epoch 101/500, Loss: 0.0097, Accuracy: 99.71%
# Epoch 102/500, Loss: 0.0347, Accuracy: 98.91%
# Epoch 103/500, Loss: 0.0568, Accuracy: 98.45%
# Epoch 104/500, Loss: 0.0474, Accuracy: 98.68%
# Epoch 105/500, Loss: 0.0244, Accuracy: 99.54%
# Epoch 106/500, Loss: 0.0074, Accuracy: 99.83%
# Epoch 107/500, Loss: 0.0230, Accuracy: 99.25%
# Epoch 108/500, Loss: 0.0419, Accuracy: 99.02%
# Epoch 109/500, Loss: 0.0284, Accuracy: 99.14%
# Epoch 110/500, Loss: 0.0491, Accuracy: 98.62%
# Epoch 111/500, Loss: 0.0166, Accuracy: 99.54%
# Epoch 112/500, Loss: 0.0384, Accuracy: 98.91%
# Epoch 113/500, Loss: 0.0197, Accuracy: 99.48%
# Epoch 114/500, Loss: 0.0433, Accuracy: 98.62%
# Epoch 115/500, Loss: 0.0437, Accuracy: 98.68%
# Epoch 116/500, Loss: 0.0190, Accuracy: 99.31%
# Epoch 117/500, Loss: 0.0075, Accuracy: 99.77%
# Epoch 118/500, Loss: 0.0066, Accuracy: 99.83%
# Epoch 119/500, Loss: 0.0090, Accuracy: 99.71%
# Epoch 120/500, Loss: 0.0119, Accuracy: 99.77%
# Epoch 121/500, Loss: 0.0153, Accuracy: 99.71%
# Epoch 122/500, Loss: 0.0208, Accuracy: 99.48%
# Epoch 123/500, Loss: 0.0377, Accuracy: 99.02%
# Epoch 124/500, Loss: 0.0325, Accuracy: 99.14%
# Epoch 125/500, Loss: 0.0201, Accuracy: 99.31%
# Epoch 126/500, Loss: 0.0197, Accuracy: 99.48%
# Epoch 127/500, Loss: 0.0225, Accuracy: 99.48%
# Epoch 128/500, Loss: 0.0217, Accuracy: 99.14%
# Epoch 129/500, Loss: 0.0089, Accuracy: 99.60%
# Epoch 130/500, Loss: 0.0053, Accuracy: 99.94%
# Epoch 131/500, Loss: 0.0045, Accuracy: 99.94%
# Epoch 132/500, Loss: 0.0019, Accuracy: 100.00%
# Epoch 133/500, Loss: 0.0037, Accuracy: 99.89%
# Epoch 134/500, Loss: 0.0058, Accuracy: 99.94%
# Epoch 135/500, Loss: 0.0100, Accuracy: 99.60%
# Epoch 136/500, Loss: 0.0030, Accuracy: 100.00%
# Epoch 137/500, Loss: 0.0034, Accuracy: 99.94%
# Epoch 138/500, Loss: 0.0039, Accuracy: 99.83%
# Epoch 139/500, Loss: 0.0056, Accuracy: 99.83%
# Epoch 140/500, Loss: 0.0081, Accuracy: 99.89%
# Epoch 141/500, Loss: 0.0154, Accuracy: 99.31%
# Epoch 142/500, Loss: 0.0201, Accuracy: 99.60%
# Epoch 143/500, Loss: 0.0147, Accuracy: 99.54%
# Epoch 144/500, Loss: 0.0201, Accuracy: 99.25%
# Epoch 145/500, Loss: 0.0482, Accuracy: 98.91%
# Epoch 146/500, Loss: 0.0163, Accuracy: 99.48%
# Epoch 147/500, Loss: 0.0114, Accuracy: 99.66%
# Epoch 148/500, Loss: 0.0119, Accuracy: 99.71%
# Epoch 149/500, Loss: 0.0195, Accuracy: 99.20%
# Epoch 150/500, Loss: 0.0318, Accuracy: 99.08%
# Epoch 151/500, Loss: 0.0164, Accuracy: 99.43%
# Epoch 152/500, Loss: 0.0123, Accuracy: 99.66%
# Epoch 153/500, Loss: 0.0349, Accuracy: 98.97%
# Epoch 154/500, Loss: 0.0814, Accuracy: 98.05%
# Epoch 155/500, Loss: 0.0189, Accuracy: 99.43%
# Epoch 156/500, Loss: 0.0154, Accuracy: 99.48%
# Epoch 157/500, Loss: 0.0093, Accuracy: 99.60%
# Epoch 158/500, Loss: 0.0094, Accuracy: 99.77%
# Epoch 159/500, Loss: 0.0241, Accuracy: 99.31%
# Epoch 160/500, Loss: 0.0105, Accuracy: 99.66%
# Epoch 161/500, Loss: 0.0109, Accuracy: 99.71%
# Epoch 162/500, Loss: 0.0184, Accuracy: 99.25%
# Epoch 163/500, Loss: 0.0038, Accuracy: 99.89%
# Epoch 164/500, Loss: 0.0065, Accuracy: 99.83%
# Epoch 165/500, Loss: 0.0040, Accuracy: 99.83%
# Epoch 166/500, Loss: 0.0089, Accuracy: 99.71%
# Epoch 167/500, Loss: 0.0123, Accuracy: 99.71%
# Epoch 168/500, Loss: 0.0164, Accuracy: 99.31%
# Epoch 169/500, Loss: 0.0270, Accuracy: 99.31%
# Epoch 170/500, Loss: 0.0063, Accuracy: 99.71%
# Epoch 171/500, Loss: 0.0585, Accuracy: 98.85%
# Epoch 172/500, Loss: 0.0365, Accuracy: 98.74%
# Epoch 173/500, Loss: 0.0632, Accuracy: 98.10%
# Epoch 174/500, Loss: 0.0287, Accuracy: 98.91%
# Epoch 175/500, Loss: 0.0166, Accuracy: 99.43%
# Epoch 176/500, Loss: 0.0105, Accuracy: 99.66%
# Epoch 177/500, Loss: 0.0039, Accuracy: 99.89%
# Epoch 178/500, Loss: 0.0030, Accuracy: 99.83%
# Epoch 179/500, Loss: 0.0019, Accuracy: 100.00%
# Epoch 180/500, Loss: 0.0030, Accuracy: 99.94%
# Epoch 181/500, Loss: 0.0137, Accuracy: 99.77%
# Epoch 182/500, Loss: 0.0250, Accuracy: 99.02%
# Epoch 183/500, Loss: 0.0379, Accuracy: 99.25%
# Epoch 184/500, Loss: 0.0473, Accuracy: 99.08%
# Epoch 185/500, Loss: 0.0343, Accuracy: 99.14%
# Epoch 186/500, Loss: 0.0289, Accuracy: 99.14%
# Epoch 187/500, Loss: 0.0242, Accuracy: 98.97%
# Epoch 188/500, Loss: 0.0088, Accuracy: 99.77%
# Epoch 189/500, Loss: 0.0063, Accuracy: 99.83%
# Epoch 190/500, Loss: 0.0073, Accuracy: 99.71%
# Epoch 191/500, Loss: 0.0073, Accuracy: 99.83%
# Epoch 192/500, Loss: 0.0040, Accuracy: 99.77%
# Epoch 193/500, Loss: 0.0076, Accuracy: 99.83%
# Epoch 194/500, Loss: 0.0068, Accuracy: 99.83%
# Epoch 195/500, Loss: 0.0032, Accuracy: 99.94%
# Epoch 196/500, Loss: 0.0043, Accuracy: 99.77%
# Epoch 197/500, Loss: 0.0147, Accuracy: 99.71%
# Epoch 198/500, Loss: 0.0115, Accuracy: 99.66%
# Epoch 199/500, Loss: 0.0259, Accuracy: 99.31%
# Epoch 200/500, Loss: 0.0246, Accuracy: 99.14%
# Epoch 201/500, Loss: 0.0176, Accuracy: 99.48%
# Epoch 202/500, Loss: 0.0205, Accuracy: 99.48%
# Epoch 203/500, Loss: 0.0447, Accuracy: 99.20%
# Epoch 204/500, Loss: 0.0098, Accuracy: 99.66%
# Epoch 205/500, Loss: 0.0079, Accuracy: 99.77%
# Epoch 206/500, Loss: 0.0125, Accuracy: 99.48%
# Epoch 207/500, Loss: 0.0171, Accuracy: 99.83%
# Epoch 208/500, Loss: 0.0096, Accuracy: 99.71%
# Epoch 209/500, Loss: 0.0041, Accuracy: 99.83%
# Epoch 210/500, Loss: 0.0033, Accuracy: 99.89%
# Epoch 211/500, Loss: 0.0058, Accuracy: 99.71%
# Epoch 212/500, Loss: 0.0092, Accuracy: 99.66%
# Epoch 213/500, Loss: 0.0048, Accuracy: 99.83%
# Epoch 214/500, Loss: 0.0094, Accuracy: 99.60%
# Epoch 215/500, Loss: 0.0028, Accuracy: 100.00%
# Epoch 216/500, Loss: 0.0013, Accuracy: 99.94%
# Epoch 217/500, Loss: 0.0032, Accuracy: 99.94%
# Epoch 218/500, Loss: 0.0017, Accuracy: 100.00%
# Epoch 219/500, Loss: 0.0005, Accuracy: 100.00%
# Epoch 220/500, Loss: 0.0027, Accuracy: 99.89%
# Epoch 221/500, Loss: 0.0012, Accuracy: 100.00%
# Epoch 222/500, Loss: 0.0020, Accuracy: 99.94%
# Epoch 223/500, Loss: 0.0020, Accuracy: 99.89%
# Epoch 224/500, Loss: 0.0147, Accuracy: 99.83%
# Epoch 225/500, Loss: 0.0216, Accuracy: 99.43%
# Epoch 226/500, Loss: 0.0378, Accuracy: 98.97%
# Epoch 227/500, Loss: 0.0600, Accuracy: 98.33%
# Epoch 228/500, Loss: 0.0362, Accuracy: 98.85%
# Epoch 229/500, Loss: 0.0232, Accuracy: 99.48%
# Epoch 230/500, Loss: 0.0175, Accuracy: 99.48%
# Epoch 231/500, Loss: 0.0115, Accuracy: 99.54%
# Epoch 232/500, Loss: 0.0724, Accuracy: 99.14%
# Epoch 233/500, Loss: 0.0353, Accuracy: 99.14%
# Epoch 234/500, Loss: 0.0584, Accuracy: 98.85%
# Epoch 235/500, Loss: 0.0256, Accuracy: 99.31%
# Epoch 236/500, Loss: 0.0104, Accuracy: 99.43%
# Epoch 237/500, Loss: 0.0129, Accuracy: 99.71%
# Epoch 238/500, Loss: 0.0111, Accuracy: 99.54%
# Epoch 239/500, Loss: 0.0056, Accuracy: 99.71%
# Epoch 240/500, Loss: 0.0035, Accuracy: 99.94%
# Epoch 241/500, Loss: 0.0115, Accuracy: 99.60%
# Epoch 242/500, Loss: 0.0180, Accuracy: 99.37%
# Epoch 243/500, Loss: 0.0182, Accuracy: 99.37%
# Epoch 244/500, Loss: 0.0051, Accuracy: 99.89%
# Epoch 245/500, Loss: 0.0032, Accuracy: 99.89%
# Epoch 246/500, Loss: 0.0044, Accuracy: 99.94%
# Epoch 247/500, Loss: 0.0012, Accuracy: 100.00%
# Epoch 248/500, Loss: 0.0016, Accuracy: 99.94%
# Epoch 249/500, Loss: 0.0029, Accuracy: 99.94%
# Epoch 250/500, Loss: 0.0011, Accuracy: 100.00%
# Epoch 251/500, Loss: 0.0046, Accuracy: 99.89%
# Epoch 252/500, Loss: 0.0203, Accuracy: 99.37%
# Epoch 253/500, Loss: 0.0293, Accuracy: 99.43%
# Epoch 254/500, Loss: 0.0151, Accuracy: 99.54%
# Epoch 255/500, Loss: 0.0097, Accuracy: 99.54%
# Epoch 256/500, Loss: 0.0174, Accuracy: 99.60%
# Epoch 257/500, Loss: 0.0099, Accuracy: 99.71%
# Epoch 258/500, Loss: 0.0122, Accuracy: 99.66%
# Epoch 259/500, Loss: 0.0114, Accuracy: 99.71%
# Epoch 260/500, Loss: 0.0043, Accuracy: 99.94%
# Epoch 261/500, Loss: 0.0058, Accuracy: 99.83%
# Epoch 262/500, Loss: 0.0045, Accuracy: 99.83%
# Epoch 263/500, Loss: 0.0083, Accuracy: 99.77%
# Epoch 264/500, Loss: 0.0032, Accuracy: 99.89%
# Epoch 265/500, Loss: 0.0040, Accuracy: 99.89%
# Epoch 266/500, Loss: 0.0033, Accuracy: 99.89%
# Epoch 267/500, Loss: 0.0048, Accuracy: 99.94%
# Epoch 268/500, Loss: 0.0190, Accuracy: 99.54%
# Epoch 269/500, Loss: 0.0118, Accuracy: 99.66%
# Epoch 270/500, Loss: 0.0236, Accuracy: 99.37%
# Epoch 271/500, Loss: 0.0185, Accuracy: 99.48%
# Epoch 272/500, Loss: 0.0071, Accuracy: 99.77%
# Epoch 273/500, Loss: 0.0109, Accuracy: 99.54%
# Epoch 274/500, Loss: 0.0028, Accuracy: 100.00%
# Epoch 275/500, Loss: 0.0080, Accuracy: 99.89%
# Epoch 276/500, Loss: 0.0091, Accuracy: 99.71%
# Epoch 277/500, Loss: 0.0296, Accuracy: 99.31%
# Epoch 278/500, Loss: 0.0097, Accuracy: 99.43%
# Epoch 279/500, Loss: 0.0289, Accuracy: 99.60%
# Epoch 280/500, Loss: 0.0131, Accuracy: 99.48%
# Epoch 281/500, Loss: 0.0291, Accuracy: 99.20%
# Epoch 282/500, Loss: 0.0020, Accuracy: 99.94%
# Epoch 283/500, Loss: 0.0065, Accuracy: 99.77%
# Epoch 284/500, Loss: 0.0064, Accuracy: 99.66%
# Epoch 285/500, Loss: 0.0071, Accuracy: 99.77%
# Epoch 286/500, Loss: 0.0024, Accuracy: 99.94%
# Epoch 287/500, Loss: 0.0034, Accuracy: 99.94%
# Epoch 288/500, Loss: 0.0016, Accuracy: 99.94%
# Epoch 289/500, Loss: 0.0014, Accuracy: 100.00%
# Epoch 290/500, Loss: 0.0036, Accuracy: 99.94%
# Epoch 291/500, Loss: 0.0014, Accuracy: 100.00%
# Epoch 292/500, Loss: 0.0020, Accuracy: 99.94%
# Epoch 293/500, Loss: 0.0530, Accuracy: 98.85%
# Epoch 294/500, Loss: 0.0296, Accuracy: 99.31%
# Epoch 295/500, Loss: 0.0281, Accuracy: 99.37%
# Epoch 296/500, Loss: 0.0638, Accuracy: 98.62%
# Epoch 297/500, Loss: 0.0208, Accuracy: 99.37%
# Epoch 298/500, Loss: 0.0063, Accuracy: 99.89%
# Epoch 299/500, Loss: 0.0077, Accuracy: 99.77%
# Epoch 300/500, Loss: 0.0039, Accuracy: 99.89%
# Epoch 301/500, Loss: 0.0100, Accuracy: 99.60%
# Epoch 302/500, Loss: 0.0142, Accuracy: 99.66%
# Epoch 303/500, Loss: 0.0101, Accuracy: 99.54%
# Epoch 304/500, Loss: 0.0122, Accuracy: 99.71%
# Epoch 305/500, Loss: 0.0155, Accuracy: 99.43%
# Epoch 306/500, Loss: 0.0046, Accuracy: 99.89%
# Epoch 307/500, Loss: 0.0107, Accuracy: 99.66%
# Epoch 308/500, Loss: 0.0143, Accuracy: 99.54%
# Epoch 309/500, Loss: 0.0119, Accuracy: 99.71%
# Epoch 310/500, Loss: 0.0018, Accuracy: 100.00%
# Epoch 311/500, Loss: 0.0073, Accuracy: 99.94%
# Epoch 312/500, Loss: 0.0084, Accuracy: 99.60%
# Epoch 313/500, Loss: 0.0059, Accuracy: 99.89%
# Epoch 314/500, Loss: 0.0065, Accuracy: 99.66%
# Epoch 315/500, Loss: 0.0014, Accuracy: 100.00%
# Epoch 316/500, Loss: 0.0024, Accuracy: 99.94%
# Epoch 317/500, Loss: 0.0014, Accuracy: 100.00%
# Epoch 318/500, Loss: 0.0092, Accuracy: 99.94%
# Epoch 319/500, Loss: 0.0110, Accuracy: 99.71%
# Epoch 320/500, Loss: 0.0070, Accuracy: 99.83%
# Epoch 321/500, Loss: 0.0050, Accuracy: 99.71%
# Epoch 322/500, Loss: 0.0015, Accuracy: 99.94%
# Epoch 323/500, Loss: 0.0023, Accuracy: 99.94%
# Epoch 324/500, Loss: 0.0059, Accuracy: 99.83%
# Epoch 325/500, Loss: 0.0022, Accuracy: 100.00%

# %%
torch.save(model, 'model.pth')

# %%
import torch
model = torch.load('model.pth',  weights_only=False)
# model.eval()
